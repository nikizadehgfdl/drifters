# %%
# !hostname;date
# Out:
# lscamd50-d.gfdl.noaa.gov
# Tue Mar 18 12:46:55 EDT 2025

# %% [markdown]
# Visualize drifter trajectories

# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

# %%
# !ls /gpfs/f5/gfdl_f/scratch/Niki.Zadeh/archive/workdirs/OM4p5_CORE2_IAF_COBALTv3_abio_csf_mle200_particles_512pes/drifter_trajectories.nc.0330
# Out:
# /gpfs/f5/gfdl_f/scratch/Niki.Zadeh/archive/workdirs/OM4p5_CORE2_IAF_COBALTv3_abio_csf_mle200_particles_512pes/drifter_trajectories.nc.0330

# %%
filepath='/home/Niki.Zadeh/platforms_CEFI/mom6/MOM6SIS2_experiments/MOM6SIS2.global_twodegree/'

# %%
#n=1


dsList=[]
for cores in ['0000']:
    trajfilename=filepath+'drifter_trajectories.nc.'+cores
    print(trajfilename)
    dsList.append(xr.open_dataset(trajfilename, decode_times=False))

for i,ds in enumerate(dsList):
    plt.plot(ds.lon[ds.drifter_num.values == 1],ds.lat[ds.drifter_num.values == 1],marker='o')
# Out:
# /home/Niki.Zadeh/platforms_CEFI/mom6/MOM6SIS2_experiments/MOM6SIS2.global_twodegree/traj/drifter_trajectories.nc.0000

# %%
for i,ds in enumerate(dsList):
    plt.plot(ds.lon[::10],ds.lat[::10],marker='o')
    plt.quiver(ds.lon[::10],ds.lat[::10],ds.uvel[::10] ,ds.vvel[::10]  )

# %%
for i,ds in enumerate(dsList):
    plt.plot(ds.day.values,ds.depth)

# %%
ods=xr.open_dataset(filepath+'19490101.ocean_static.nc')
plt.pcolormesh(ods.geolon,ods.geolat,ods.wet)
for i,ds in enumerate(dsList):
    plt.plot(ds.lon[ds.drifter_num.values == 1],ds.lat[ds.drifter_num.values == 1],marker='o')
# Out:
# /tmp/ipykernel_1217098/1304311151.py:2: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(ods.geolon,ods.geolat,ods.wet)

# %%
#n=16
filepath='/home/Niki.Zadeh/platforms_CEFI/mom6/MOM6SIS2_experiments/MOM6SIS2.global_twodegree/'
#filepath='/gpfs/f5/gfdl_f/scratch/Niki.Zadeh/archive/misc/MOM6SIS2_experiments/MOM6SIS2.global_twodegree/'
#trajfilename=filepath+'drifter_trajectories.nc.0058'
#filepath='/gpfs/f5/gfdl_f/scratch/Niki.Zadeh/archive/workdirs/OM4p5_CORE2_IAF_COBALTv3_abio_csf_mle200_particles_512pes/'

dsList=[]
for cores in ['0005','0009']:
    trajfilename=filepath+'drifter_trajectories.nc.'+cores
    print(trajfilename)
    dsList.append(xr.open_dataset(trajfilename, decode_times=False))

for i,ds in enumerate(dsList):
    plt.plot(ds.lon[ds.drifter_num.values == 1],ds.lat[ds.drifter_num.values == 1],marker='o')
# Out:
# /home/Niki.Zadeh/platforms_CEFI/mom6/MOM6SIS2_experiments/MOM6SIS2.global_twodegree/drifter_trajectories.nc.0005
# /home/Niki.Zadeh/platforms_CEFI/mom6/MOM6SIS2_experiments/MOM6SIS2.global_twodegree/drifter_trajectories.nc.0009

# %%
for i,ds in enumerate(dsList):
    plt.plot(ds.day.values,ds.depth, linestyle='None', marker='.')

# %%
#n=64
filepath='/home/Niki.Zadeh/platforms_CEFI/mom6/MOM6SIS2_experiments/MOM6SIS2.global_twodegree/'
#filepath='/gpfs/f5/gfdl_f/scratch/Niki.Zadeh/archive/misc/MOM6SIS2_experiments/MOM6SIS2.global_twodegree/'
#trajfilename=filepath+'drifter_trajectories.nc.0058'
#filepath='/gpfs/f5/gfdl_f/scratch/Niki.Zadeh/archive/workdirs/OM4p5_CORE2_IAF_COBALTv3_abio_csf_mle200_particles_512pes/'

dsList=[]
for cores in ['0026','0034']:
    trajfilename=filepath+'drifter_trajectories.nc.'+cores
    print(trajfilename)
    dsList.append(xr.open_dataset(trajfilename, decode_times=False))

for i,ds in enumerate(dsList):
    plt.plot(ds.lon[ds.drifter_num.values == 1],ds.lat[ds.drifter_num.values == 1],marker='o')
# Out:
# /home/Niki.Zadeh/platforms_CEFI/mom6/MOM6SIS2_experiments/MOM6SIS2.global_twodegree/drifter_trajectories.nc.0026
# /home/Niki.Zadeh/platforms_CEFI/mom6/MOM6SIS2_experiments/MOM6SIS2.global_twodegree/drifter_trajectories.nc.0034

# %%
#n=32

dsList=[]
for cores in ['0013']:
    trajfilename=filepath+'drifter_trajectories.nc.'+cores
    print(trajfilename)
    dsList.append(xr.open_dataset(trajfilename, decode_times=False))

for i,ds in enumerate(dsList):
    plt.plot(ds.lon[:],ds.lat[:],marker='o')
# Out:
# /home/Niki.Zadeh/platforms_CEFI/mom6/MOM6SIS2_experiments/MOM6SIS2.global_twodegree/drifter_trajectories.nc.0013

# %%
ds=xr.open_dataset('/gpfs/f5/gfdl_f/scratch/Niki.Zadeh/archive/workdirs/OM_1deg_JRA1.5_128x1o/drifter_trajectories.nc.0074')

# %%
ods=xr.open_dataset('/gpfs/f5/gfdl_f/scratch/Niki.Zadeh/archive/workdirs/OM_1deg_JRA1.5_128x1o/19580101.ocean_static.nc')
plt.pcolormesh(ods.geolon,ods.geolat,ods.wet)
plt.plot(ds.lon[ds.drifter_num.values == 1],ds.lat[ds.drifter_num.values == 1],marker='o')
# Out:
# /gpfs/f5/gfdl_f/scratch/Niki.Zadeh/tmp/ipykernel_2387861/304938796.py:2: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(ods.geolon,ods.geolat,ods.wet)

# %%
plt.plot(ds.vvel)
plt.plot(ds.uvel)

# %%
plt.plot(ds.depth)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the vector field
x, y = np.meshgrid(np.linspace(-5, 5, 20), np.linspace(-5, 5, 20))
u = -y  # x-component of the vector field
v = x   # y-component of the vector field

# Create the plot
plt.figure(figsize=(8, 8))
plt.quiver(x, y, u, v, color='b')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Velocity Field')
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True)
plt.show()
